# %%
import cv2
import numpy as np

# %%
# !wget -O cathedral.zip http://grail.cs.washington.edu/projects/photomontage/data/cathedral.zip && unzip -o cathedral.zip
# !wget -O my_dataset.zip https://drive.google.com/uc?id=1Z7iD5vygS4th1UEA9uH_iplNuCfPWtk-&export=download 
# !unzip my_dataset.zip  

#https://drive.google.com/uc?id=1y4Oht73Sx2BurzkfGOltuavuCMCHTwQw&export=download
# !wget -O example_images.zip https://drive.google.com/uc?id=1y4Oht73Sx2BurzkfGOltuavuCMCHTwQw&export=download 
# !unzip example_images.zip
# Out:
# --2022-11-10 13:38:11--  http://grail.cs.washington.edu/projects/photomontage/data/cathedral.zip
# Resolving grail.cs.washington.edu (grail.cs.washington.edu)... 128.208.5.93, 2607:4000:200:14::5d
# Connecting to grail.cs.washington.edu (grail.cs.washington.edu)|128.208.5.93|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1342082 (1.3M) [application/zip]
# Saving to: ‘cathedral.zip’
#
# cathedral.zip       100%[===================>]   1.28M  2.46MB/s    in 0.5s
#
# 2022-11-10 13:38:12 (2.46 MB/s) - ‘cathedral.zip’ saved [1342082/1342082]
#
# Archive:  cathedral.zip
#   inflating: cathedral/d001.jpg
#   inflating: cathedral/d002.jpg
#   inflating: cathedral/d003.jpg
#   inflating: cathedral/d004.jpg
#   inflating: cathedral/d005.jpg
#   inflating: cathedral/result.png
# --2022-11-10 13:38:12--  https://drive.google.com/uc?id=1Z7iD5vygS4th1UEA9uH_iplNuCfPWtk-
# ...

# %%
if 'google.colab' in str(get_ipython()):
  from google.colab.patches import cv2_imshow
  imshow = cv2_imshow
else:
  imshow = cv2.imshow

# %%
files = [
    './cathedral/d001.jpg',      
    './cathedral/d002.jpg',      
    './cathedral/d003.jpg',      
    './cathedral/d004.jpg',      
    './cathedral/d005.jpg',      
    './cathedral/result.png',
]
files_2 = [
    './my_dataset/d001.jpg',
    './my_dataset/d002.jpg',
    './my_dataset/d003.jpg',
    './my_dataset/d004.jpg',
    './my_dataset/d005.jpg',
]
files_3 = [
  './example_images/d001.png',  
  './example_images/d002.png',  
  './example_images/d003.png',   
]

# %%
images = [cv2.imread(f, 1) for f in files]
own_images = [cv2.imread(f, 1) for f in files_2]
example_images = [cv2.imread(f, 1) for f in files_3]

# %%
imshow(np.concatenate(own_images[0:3], 1))
imshow(np.concatenate(own_images[3:6], 1))
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
imshow(np.concatenate(images[0:3], 1))
imshow(np.concatenate(images[3:6], 1))
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
imshow(np.concatenate(example_images[0:3], 1))
# Out:
# <PIL.Image.Image image mode=RGB size=1800x309 at 0x7F5399A60C10>
